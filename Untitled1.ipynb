# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
# import and create datafram 
df = pd.read_csv(r'data.csv')
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
# drop unnescessary colums like employerrId, orighiredate_key, recorddate_key, birthdate_key,terminationdate_key, 
# store_name,gener_full. termreason_desc, termtype_desc , 
df = df.drop(['recorddate_key', 
              'birthdate_key', 
              'orighiredate_key', 
              'terminationdate_key', 
              'gender_full', 'store_name', 
              'termreason_desc', 
              'termtype_desc',
              'EmployeeID'],
             axis = 1
            )
df.head()
# Out:
#    age  length_of_service  city_name department_name job_title gender_short  \
# 0   52                 17  Vancouver       Executive       CEO            M
# 1   53                 18  Vancouver       Executive       CEO            M
# 2   54                 19  Vancouver       Executive       CEO            M
# 3   55                 20  Vancouver       Executive       CEO            M
# 4   56                 21  Vancouver       Executive       CEO            M
#
#    STATUS_YEAR  STATUS BUSINESS_UNIT
# 0         2006  ACTIVE    HEADOFFICE
# 1         2007  ACTIVE    HEADOFFICE
# 2         2008  ACTIVE    HEADOFFICE
# 3         2009  ACTIVE    HEADOFFICE
# 4         2010  ACTIVE    HEADOFFICE

# %%
df.shape
# in this dataset, we have 49653 rows and 9 columns
# 8 features and 1 Target variable
# Out:
# (49653, 9)

# %%
city_names = df['city_name'].tolist()
unique_city_names = set (city_names)
len(unique_city_names)

# we have 40 unique cities
# Out:
# 40

# %%
department_names = df['department_name'].tolist()
unique_department_names = set (department_names)
len(unique_department_names)

# we have 21 unique cities
# Out:
# 21

# %%
job_title = df['job_title'].tolist()
unique_job_title = set (job_title)
len(unique_job_title)

# we have 47 unique cities
# Out:
# 47

# %%
BUSINESS_UNIT = df['BUSINESS_UNIT'].tolist()
unique_BUSINESS_UNIT= set (BUSINESS_UNIT)
len(unique_BUSINESS_UNIT)

# we have 2 unique cities
# Out:
# 2

# %%
# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object', 'category']).columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns

print("\nCategorical columns:", categorical_cols)
print("Numerical columns:", numerical_cols)
# Out:
# Categorical columns: Index([], dtype='object')
# Numerical columns: Index(['age', 'length_of_service', 'STATUS_YEAR'], dtype='object')

# %%
# Create preprocessing steps
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_cols)
    ])

# %%
# Create a pipeline with preprocessor and random forest classifier
rf_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(n_estimators=100, min_samples_split=3, max_depth=15, random_state=42))
])

# %%
# Split the dataset into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Fit the pipeline
rf_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['age', 'length_of_service', 'STATUS_YEAR'], dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index([], dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(max_depth=15, min_samples_split=3,
#                                         random_state=42))])

# %%
# Evaluate the model
train_accuracy = rf_pipeline.score(X_train, y_train)
test_accuracy = rf_pipeline.score(X_test, y_test)

print(f"\nTraining Accuracy: {train_accuracy:.4f}")
print(f"Testing Accuracy: {test_accuracy:.4f}")

# Print classification report
y_pred = rf_pipeline.predict(X_test)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Training Accuracy: 0.9851
# Testing Accuracy: 0.9859
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       ACTIVE       0.99      1.00      0.99     12058
#   TERMINATED       0.86      0.60      0.71       356
#
#     accuracy                           0.99     12414
#    macro avg       0.93      0.80      0.85     12414
# weighted avg       0.98      0.99      0.98     12414

# %%
# Save the model
import joblib
joblib.dump(model, 'random_forest_model.joblib')
print("\nModel saved in random_forest_model.joblib")
# Out:
# Model saved in random_forest_model.joblib
